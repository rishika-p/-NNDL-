# %% [markdown]
# <a href="https://colab.research.google.com/github/rishika-p/-NNDL-/blob/main/assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=symbols('x')
f=x**4+3*(x**2)+10
p=diff(f,x) 
print("differenciation of given equation is ",p)
A=int(input("enter x value:"))
iter=1 
n=0.001
epoch=100
while (iter<=epoch) :
   Q=p.subs(x,A)
   print("p",Q)
   delta_x=-n*Q
   print("delta(x) =",delta_x)
   new_x = A + delta_x
   print("x =",new_x)
   iter= iter + 1
   A=new_x
print("FINAL VALUE OF X IS ",A)
print("MINIMUM VALUE OF GIVEN EQUATION IS",f.subs(x,A))
# Out:
# differenciation of given equation is  4*x**3 + 6*x
# enter x value:3
# p 126
# delta(x) = -0.126000000000000
# x = 2.87400000000000
# p 112.199534496000
# delta(x) = -0.112199534496000
# x = 2.76180046550400
# p 100.833796892960
# delta(x) = -0.100833796892960
# x = 2.66096666861104
# p 91.3322909679575
# delta(x) = -0.0913322909679575
# x = 2.56963437764308
# p 83.2872035990828
# delta(x) = -0.0832872035990828
# x = 2.48634717404400
# p 76.3997029077333
# delta(x) = -0.0763997029077333
# x = 2.40994747113627
# p 70.4461077918941
# delta(x) = -0.0704461077918941
# x = 2.33950136334437
# p 65.2558671428812
# delta(x) = -0.0652558671428812
# x = 2.27424549620149
# p 60.6968156720593
# delta(x) = -0.0606968156720593
# x = 2.21354868052943
# p 56.6650555587187
# delta(x) = -0.0566650555587187
# x = 2.15688362497071
# p 53.0778602464052
# delta(x) = -0.0530778602464052
# x = 2.10380576472431
# p 49.8686008709421
# delta(x) = -0.0498686008709421
# x = 2.05393716385337
# p 46.9830557313460
# delta(x) = -0.0469830557313460
# x = 2.00695410812202
# p 44.3766838146558
# delta(x) = -0.0443766838146558
# x = 1.96257742430736
# p 42.0125820590525
# delta(x) = -0.0420125820590525
# x = 1.92056484224831
# p 39.8599352186183
# delta(x) = -0.0398599352186183
# x = 1.88070490702969
# p 37.8928257343751
# delta(x) = -0.0378928257343751
# x = 1.84281208129532
# p 36.0893101701734
# delta(x) = -0.0360893101701734
# x = 1.80672277112515
# p 34.4306954095312
# delta(x) = -0.0344306954095312
# x = 1.77229207571561
# p 32.9009662172732
# delta(x) = -0.0329009662172732
# x = 1.73939110949834
# p 31.4863286747040
# delta(x) = -0.0314863286747040
# x = 1.70790478082364
# p 30.1748431650655
# delta(x) = -0.0301748431650655
# x = 1.67772993765857
# p 28.9561271798998
# delta(x) = -0.0289561271798998
# x = 1.64877381047867
# p 27.8211130139424
# delta(x) = -0.0278211130139424
# x = 1.62095269746473
# p 26.7618489433394
# delta(x) = -0.0267618489433394
# x = 1.59419084852139
# p 25.7713351013826
# delta(x) = -0.0257713351013826
# x = 1.56841951342001
# p 24.8433872294246
# delta(x) = -0.0248433872294246
# x = 1.54357612619058
# p 23.9725229653415
# delta(x) = -0.0239725229653415
# x = 1.51960360322524
# p 23.1538664638600
# delta(x) = -0.0231538664638600
# x = 1.49644973676138
# p 22.3830680127734
# delta(x) = -0.0223830680127734
# x = 1.47406666874861
# p 21.6562359821917
# delta(x) = -0.0216562359821917
# x = 1.45241043276642
# p 20.9698789685539
# delta(x) = -0.0209698789685539
# x = 1.43144055379786
# p 20.3208564066303
# delta(x) = -0.0203208564066303
# x = 1.41111969739123
# p 19.7063362475451
# delta(x) = -0.0197063362475451
# x = 1.39141336114369
# p 19.1237585587405
# delta(x) = -0.0191237585587405
# x = 1.37228960258495
# p 18.5708041077040
# delta(x) = -0.0185708041077040
# x = 1.35371879847724
# p 18.0453671565629
# delta(x) = -0.0180453671565629
# x = 1.33567343132068
# p 17.5455318279978
# delta(x) = -0.0175455318279978
# x = 1.31812789949268
# p 17.0695515110269
# delta(x) = -0.0170695515110269
# x = 1.30105834798165
# p 16.6158308632667
# delta(x) = -0.0166158308632667
# x = 1.28444251711839
# p 16.1829100383011
# delta(x) = -0.0161829100383011
# x = 1.26825960708009
# p 15.7694508259727
# delta(x) = -0.0157694508259727
# x = 1.25249015625411
# p 15.3742244422265
# delta(x) = -0.0153742244422265
# x = 1.23711593181189
# p 14.9961007455596
# delta(x) = -0.0149961007455596
# x = 1.22211983106633
# p 14.6340386907409
# delta(x) = -0.0146340386907409
# x = 1.20748579237559
# p 14.2870778584915
# delta(x) = -0.0142870778584915
# x = 1.19319871451710
# p 13.9543309232893
# delta(x) = -0.0139543309232893
# x = 1.17924438359381
# p 13.6349769411685
# delta(x) = -0.0136349769411685
# x = 1.16560940665264
# p 13.3282553559936
# delta(x) = -0.0133282553559936
# x = 1.15228115129664
# p 13.0334606367259
# delta(x) = -0.0130334606367259
# x = 1.13924769065992
# p 12.7499374700965
# delta(x) = -0.0127499374700965
# x = 1.12649775318982
# p 12.4770764432211
# delta(x) = -0.0124770764432211
# x = 1.11402067674660
# p 12.2143101593127
# delta(x) = -0.0122143101593127
# x = 1.10180636658729
# p 11.9611097370228
# delta(x) = -0.0119611097370228
# x = 1.08984525685026
# p 11.7169816502587
# delta(x) = -0.0117169816502587
# x = 1.07812827520001
# p 11.4814648707545
# delta(x) = -0.0114814648707545
# x = 1.06664681032925
# p 11.2541282803472
# delta(x) = -0.0112541282803472
# x = 1.05539268204890
# p 11.0345683239472
# delta(x) = -0.0110345683239472
# x = 1.04435811372496
# p 10.8224068776834
# delta(x) = -0.0108224068776834
# x = 1.03353570684727
# p 10.6172893097327
# delta(x) = -0.0106172893097327
# x = 1.02291841753754
# p 10.4188827139742
# delta(x) = -0.0104188827139742
# x = 1.01249953482357
# p 10.2268742989017
# delta(x) = -0.0102268742989017
# x = 1.00227266052466
# p 10.0409699162273
# delta(x) = -0.0100409699162273
# x = 0.992231690608437
# p 9.86089271535631
# delta(x) = -0.00986089271535632
# x = 0.982370797893081
# p 9.68638191144664
# delta(x) = -0.00968638191144664
# x = 0.972684415981634
# p 9.51719165610966
# delta(x) = -0.00951719165610966
# x = 0.963167224325525
# p 9.35309000099000
# delta(x) = -0.00935309000099000
# x = 0.953814134324535
# p 9.19385794550360
# delta(x) = -0.00919385794550360
# x = 0.944620276379031
# p 9.03928856093071
# delta(x) = -0.00903928856093071
# x = 0.935580987818100
# p 8.88918618387199
# delta(x) = -0.00888918618387199
# x = 0.926691801634228
# p 8.74336567279360
# delta(x) = -0.00874336567279360
# x = 0.917948435961435
# p 8.60165172202392
# delta(x) = -0.00860165172202392
# x = 0.909346784239411
# p 8.46387822812932
# delta(x) = -0.00846387822812932
# x = 0.900882906011282
# p 8.32988770409900
# delta(x) = -0.00832988770409900
# x = 0.892553018307182
# p 8.19953073721627
# delta(x) = -0.00819953073721628
# x = 0.884353487569966
# p 8.07266548689251
# delta(x) = -0.00807266548689251
# x = 0.876280822083074
# p 7.94915721909615
# delta(x) = -0.00794915721909615
# x = 0.868331664863978
# p 7.82887787432801
# delta(x) = -0.00782887787432801
# x = 0.860502786989650
# p 7.71170566637873
# delta(x) = -0.00771170566637873
# x = 0.852791081323271
# p 7.59752470936051
# delta(x) = -0.00759752470936051
# x = 0.845193556613910
# p 7.48622467073405
# delta(x) = -0.00748622467073405
# x = 0.837707331943176
# p 7.37770044825860
# delta(x) = -0.00737770044825860
# x = 0.830329631494918
# p 7.27185186897791
# delta(x) = -0.00727185186897791
# x = 0.823057779625940
# p 7.16858340852239
# delta(x) = -0.00716858340852239
# x = 0.815889196217417
# p 7.06780392915867
# delta(x) = -0.00706780392915867
# x = 0.808821392288259
# p 6.96942643515344
# delta(x) = -0.00696942643515344
# x = 0.801851965853105
# p 6.87336784414201
# delta(x) = -0.00687336784414201
# x = 0.794978598008963
# p 6.77954877330287
# delta(x) = -0.00677954877330287
# x = 0.788199049235660
# p 6.68789333924094
# delta(x) = -0.00668789333924094
# x = 0.781511155896420
# p 6.59832897057301
# delta(x) = -0.00659832897057301
# x = 0.774912826925847
# p 6.51078623229252
# delta(x) = -0.00651078623229252
# x = 0.768402040693554
# p 6.42519866106568
# delta(x) = -0.00642519866106568
# x = 0.761976842032488
# p 6.34150261068007
# delta(x) = -0.00634150261068007
# x = 0.755635339421808
# p 6.25963710692868
# delta(x) = -0.00625963710692868
# x = 0.749375702314879
# p 6.17954371126984
# delta(x) = -0.00617954371126984
# x = 0.743196158603610
# p 6.10116639265503
# delta(x) = -0.00610116639265503
# x = 0.737094992210955
# p 6.02445140696395
# delta(x) = -0.00602445140696395
# x = 0.731070540803991
# p 5.94934718352960
# delta(x) = -0.00594934718352960
# x = 0.725121193620461
# p 5.87580421827562
# delta(x) = -0.00587580421827562
# x = 0.719245389402186
# p 5.80377497302443
# delta(x) = -0.00580377497302443
# x = 0.713441614429161
# FINAL VALUE OF X IS  0.713441614429161
# MINIMUM VALUE OF GIVEN EQUATION IS 11.7860767296679
